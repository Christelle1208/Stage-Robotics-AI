# %%
# !pip install lerobot
# !HF_TOKEN="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" lerobot-train \
--dataset.repo_id=Christelle04/pick-cube-640 \
--dataset.video_backend=pyav \
--policy.type=smolvla \
--steps=30000 \
--output_dir=outputs/train/smolvla-pick-cube-640 \
--job_name=smolvla_pick-cube-640 \
--policy.device=cuda \
--wandb.enable=false \
--policy.repo_id=Christelle04/smolvla_pick_cube
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 23.5 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 88.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 10.2 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 68.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# Clearly define dataset "ID" and "path" to avoid command errors
# - Local dataset: DATASET_ID as local/xxx, and provide DATASET_ROOT
# - Hub dataset: DATASET_ID as your-name/your-repo, and remove --dataset.root
DATASET_ID=Christelle04/pick-cube-640

export CUDA_VISIBLE_DEVICES=0

# Start SmolVLA fine-tuning
lerobot-train \
  --policy.type smolvla \
  --policy.pretrained_path lerobot/smolvla_base \
  --dataset.repo_id Christelle04/pick-cube-640 \
  --batch_size 64 \
  --steps 20000 \
  --output_dir outputs/train/smolvla_finetuned \
  --job_name smolvla_finetuning \
  --policy.device cuda \
  --policy.optimizer_lr 1e-4 \
  --policy.scheduler_warmup_steps 1000 \
  --policy.push_to_hub false \
  --save_checkpoint true \
  --save_freq 5000 \
  --wandb.enable false \
  --wandb.project smolvla_finetuning

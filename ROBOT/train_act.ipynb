# %%
# !HF_TOKEN="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" lerobot-train \
  --dataset.repo_id=Christelle04/pick-cube-640 \
  --dataset.video_backend=pyav \
  --policy.type=act \
  --steps=30000 \
  --output_dir=outputs/train/pick-cube-640 \
  --job_name=act_pick-cube-640 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=Christelle04/my_policy
